# %% [markdown]
# # BoTIoT Cleaning (%5 ver.)

# %% [markdown]
# ## Setup

# %%
import pandas as pd
import numpy as np
import pandas as pd
from pathlib import Path
import config

# %%
root = '../IDS datasets/BotIoT/5%/5%/All features/'; root=Path(root)
df1 = pd.read_csv(root / 'UNSW_2018_IoT_Botnet_Full5pc_1.csv')
df2 = pd.read_csv(root / 'UNSW_2018_IoT_Botnet_Full5pc_2.csv')
df3 = pd.read_csv(root / 'UNSW_2018_IoT_Botnet_Full5pc_3.csv')
df4 = pd.read_csv(root / 'UNSW_2018_IoT_Botnet_Full5pc_4.csv')
# Out:
# C:\Users\taznk\AppData\Local\Temp\ipykernel_16392\2468190694.py:2: DtypeWarning: Columns (7,9) have mixed types. Specify dtype option on import or set low_memory=False.
#   df1 = pd.read_csv(root / 'UNSW_2018_IoT_Botnet_Full5pc_1.csv')
# C:\Users\taznk\AppData\Local\Temp\ipykernel_16392\2468190694.py:3: DtypeWarning: Columns (7,9) have mixed types. Specify dtype option on import or set low_memory=False.
#   df2 = pd.read_csv(root / 'UNSW_2018_IoT_Botnet_Full5pc_2.csv')
# C:\Users\taznk\AppData\Local\Temp\ipykernel_16392\2468190694.py:4: DtypeWarning: Columns (7,9) have mixed types. Specify dtype option on import or set low_memory=False.
#   df3 = pd.read_csv(root / 'UNSW_2018_IoT_Botnet_Full5pc_3.csv')
# C:\Users\taznk\AppData\Local\Temp\ipykernel_16392\2468190694.py:5: DtypeWarning: Columns (7,9) have mixed types. Specify dtype option on import or set low_memory=False.
#   df4 = pd.read_csv(root / 'UNSW_2018_IoT_Botnet_Full5pc_4.csv')

# %%
df1.head()
# Out:
#    pkSeqID         stime flgs  flgs_number proto  proto_number  \
# 0        1  1.528089e+09    e            1   tcp             1
# 1        2  1.528089e+09    e            1   arp             2
# 2        3  1.528089e+09    e            1   tcp             1
# 3        4  1.528089e+09    e            1   tcp             1
# 4        5  1.528089e+09    e            1   tcp             1
#
#              saddr  sport            daddr dport  ...  AR_P_Proto_P_DstIP  \
# 0  192.168.100.147  49960    192.168.100.7    80  ...             1.12704
# 1    192.168.100.7     -1  192.168.100.147    -1  ...         15267.20000
# 2  192.168.100.147  49962    192.168.100.7    80  ...             1.12704
# 3  192.168.100.147  49964    192.168.100.7    80  ...             1.12704
# 4  192.168.100.147  49966    192.168.100.7    80  ...             1.12704
#
#    N_IN_Conn_P_DstIP N_IN_Conn_P_SrcIP  AR_P_Proto_P_Sport  \
# 0                 96                75            1.133720
# ...

# %%
df2.head()
# Out:
#    pkSeqID         stime flgs  flgs_number proto  proto_number  \
# 0  1000001  1.528085e+09    e            1   udp             3
# 1  1000002  1.528085e+09    e            1   udp             3
# 2  1000003  1.528085e+09    e            1   udp             3
# 3  1000004  1.528085e+09    e            1   udp             3
# 4  1000005  1.528085e+09    e            1   udp             3
#
#              saddr  sport          daddr dport  ...  AR_P_Proto_P_DstIP  \
# 0  192.168.100.148  37153  192.168.100.6    80  ...            0.319943
# 1  192.168.100.148  37154  192.168.100.6    80  ...            0.319943
# 2  192.168.100.148  37155  192.168.100.6    80  ...            0.319943
# 3  192.168.100.148  37156  192.168.100.6    80  ...            0.319943
# 4  192.168.100.148  37157  192.168.100.6    80  ...            0.319943
#
#    N_IN_Conn_P_DstIP N_IN_Conn_P_SrcIP  AR_P_Proto_P_Sport  \
# 0                100               100            0.319979
# ...

# %%
df3.head()
# Out:
#    pkSeqID         stime flgs  flgs_number proto  proto_number  \
# 0  2000001  1.528096e+09  e s            2   tcp             1
# 1  2000002  1.528096e+09  e s            2   tcp             1
# 2  2000003  1.528096e+09  e s            2   tcp             1
# 3  2000004  1.528096e+09  e s            2   tcp             1
# 4  2000005  1.528096e+09  e s            2   tcp             1
#
#              saddr  sport          daddr dport  ...  AR_P_Proto_P_DstIP  \
# 0  192.168.100.148  64480  192.168.100.3    80  ...            0.326786
# 1  192.168.100.148  64481  192.168.100.3    80  ...            0.326786
# 2  192.168.100.148  64484  192.168.100.3    80  ...            0.326786
# 3  192.168.100.148  64485  192.168.100.3    80  ...            0.326786
# 4  192.168.100.148  64490  192.168.100.3    80  ...            0.326786
#
#    N_IN_Conn_P_DstIP N_IN_Conn_P_SrcIP  AR_P_Proto_P_Sport  \
# 0                100                46            0.339821
# ...

# %%
df4.head()
# Out:
#    pkSeqID         stime flgs  flgs_number proto  proto_number  \
# 0  3000001  1.528099e+09    e            1   udp             3
# 1  3000002  1.528099e+09    e            1   udp             3
# 2  3000003  1.528099e+09    e            1   udp             3
# 3  3000004  1.528099e+09    e            1   udp             3
# 4  3000005  1.528099e+09    e            1   udp             3
#
#              saddr sport          daddr dport  ...  AR_P_Proto_P_DstIP  \
# 0  192.168.100.147  6226  192.168.100.3    80  ...             1.09825
# 1  192.168.100.147  6227  192.168.100.3    80  ...             1.09825
# 2  192.168.100.147  6228  192.168.100.3    80  ...             1.09825
# 3  192.168.100.147  6229  192.168.100.3    80  ...             1.09825
# 4  192.168.100.147  6230  192.168.100.3    80  ...             1.09825
#
#    N_IN_Conn_P_DstIP N_IN_Conn_P_SrcIP  AR_P_Proto_P_Sport  \
# 0                100               100             1.09827
# ...

# %%
dfs = [df1, df2, df3, df4]
[len(df) for df in dfs]
# Out:
# [1000000, 1000000, 1000000, 668522]

# %%
data = pd.concat([d for d in dfs])

# %%
for d in dfs: del d

# %%
data['category'].unique()
# Out:
# array(['DoS', 'DDoS', 'Normal', 'Reconnaissance', 'Theft'], dtype=object)

# %% [markdown]
# ## Cleaning

# %%
# na
for c in data.columns:
    n_na = pd.isna(data[c]).any()
    if n_na > 1:
        print(f'{c} -> {n_na} / {len(data)}')

# %%
pd.isna(data).any().sum()
# Out:
# np.int64(0)

# %%
# duplicates
len(data) - len(data.drop_duplicates())
# Out:
# 0

# %%
# check cats
categorical = [
    'attack', 'category', 'subcategory', 'state', 'saddr', 'daddr', 'flgs', 'flgs_number'
]
for c in categorical:
    print()
    print(c)
    print(data[c].unique())
# Out:
# attack
# [1 0]
#
# category
# ['DoS' 'DDoS' 'Normal' 'Reconnaissance' 'Theft']
#
# subcategory
# ['HTTP' 'TCP' 'UDP' 'Normal' 'OS_Fingerprint' 'Service_Scan'
#  'Data_Exfiltration' 'Keylogging']
#
# state
# ['RST' 'CON' 'REQ' 'INT' 'URP' 'FIN' 'ACC' 'NRS' 'ECO' 'TST' 'MAS']
#
# saddr
# ['192.168.100.147' '192.168.100.7' '192.168.100.148' '192.168.100.6'
#  '192.168.100.149' '192.168.100.150' '192.168.100.5' '192.168.100.3'
#  '192.168.100.1' '192.168.100.4' '192.168.100.27'
#  'fe80::250:56ff:febe:254' '192.168.100.46' 'fe80::250:56ff:febe:26db'
#  'fe80::250:56ff:febe:e9d9' 'fe80::c0c0:aa20:45b9:bdd9'
#  'fe80::250:56ff:febe:89ee' 'fe80::2c6a:ff9b:7e14:166a'
#  'fe80::250:56ff:febe:bf1a' 'fe80::250:56ff:febe:c038' '192.168.100.55']
#
# daddr
# ['192.168.100.7' '192.168.100.147' '192.168.100.6' '192.168.100.148'
#  '192.168.100.5' '192.168.100.3' '192.168.100.149' '192.168.100.150'
#  '192.168.100.4' '27.124.125.250' '192.168.100.1' '192.168.100.27'
# ...

# %%
# no cleaning needed 
data.to_csv(config.INTERM_DIR / 'demo_botiot_clean.csv', index=False)
